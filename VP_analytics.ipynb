# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm 
from statsmodels.formula.api import ols
# !pip install scipy
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import sklearn.model_selection
from sklearn.tree import DecisionTreeRegressor
from sklearn import metrics
from statsmodels.stats.outliers_influence import variance_inflation_factor
import math
from sklearn.metrics import confusion_matrix

# Optional - Use the script below to make sure that the file exists 
import os
path = "data_sa.xlsx" # Name here the file you are looking for
if os.path.exists(path):
    print("File found!")
else:
    print(f"File not found at: {path}")
# Out:
# ...
# File found!

# %%
# Load Data set xlsx file for sentiment analysis.
file_path = 'Data_set.xlsx'

data = pd.read_excel('data_sa.xlsx')
data.head()
# Out:
#                                             abstract  \
# 0  Apple and Qualcomm said they had agreed to dis...
# 1  Last year, with much fanfare, the tech giant u...
# 2  The company said it would add to its record re...
# 3  In every region, farmers and scientists are tr...
# 4  After two years of bitter patent battles acros...
#
#                                              web_url  \
# 0  https://www.nytimes.com/2019/04/16/technology/...
# 1  https://www.nytimes.com/2019/04/27/technology/...
# 2  https://www.nytimes.com/2019/04/30/technology/...
# 3  https://www.nytimes.com/2019/04/30/dining/farm...
# 4  https://www.nytimes.com/2019/04/17/business/de...
#
#                                              snippet  \
# 0  Apple and Qualcomm said they had agreed to dis...
# 1  Last year, with much fanfare, the tech giant u...
# 2  The company said it would add to its record re...
# 3  In every region, farmers and scientists are tr...
# ...
